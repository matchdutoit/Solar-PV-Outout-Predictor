# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/readyforweath.csv')
weath = pd.read_csv('data/weather_unique.csv')

# %%
df.head().T
# Out:
#                                    0                     1  \
# lat                            36.82                 36.82
# lon                          -119.76               -119.76
# city                          Fresno                Fresno
# actualkwh                     215457                193488
# irradiancekwh                 278138                261959
# pr                          0.774641              0.738618
# mount_type      Fixed - Roof Mounted  Fixed - Roof Mounted
# koeppen                     Moderate              Moderate
# capacity_dc_kw                161.12                161.12
# tilt                            30.0                  30.0
# azimuth                        180.0                 180.0
# paneltype                       mono                  mono
# cellcategory                 Premium               Premium
# cod                       2008-09-05            2008-09-05
# invertermake                  SatCon                SatCon
# invertermodel         AE-135-60-PV-A        AE-135-60-PV-A
# panelmake                   SunPower              SunPower
# panelmodel           PL-EVER-ES-190P       PL-EVER-ES-190P
# year                            2009                  2010
#
#                                    2                     3  \
# lat                            34.02                 34.02
# lon                          -118.11               -118.11
# city                      Montebello            Montebello
# actualkwh                     288247                252797
# irradiancekwh                 416119                409327
# pr                          0.692703              0.617592
# mount_type      Fixed - Roof Mounted  Fixed - Roof Mounted
# koeppen                     Moderate              Moderate
# capacity_dc_kw                 243.2                 243.2
# tilt                            30.0                  30.0
# azimuth                        180.0                 180.0
# paneltype                       mono                  mono
# cellcategory                 Premium               Premium
# cod                       2007-08-01            2007-08-01
# invertermake                 Xantrex               Xantrex
# invertermodel           PV225S-480-P          PV225S-480-P
# panelmake                   SunPower              SunPower
# panelmodel           PL-EVER-ES-190P       PL-EVER-ES-190P
# year                            2009                  2010
#
#                                    4
# lat                            33.78
# lon                          -117.23
# city                          Perris
# actualkwh                      56125
# irradiancekwh                  81675
# pr                          0.687175
# mount_type      Fixed - Roof Mounted
# koeppen                     Moderate
# capacity_dc_kw                46.592
# tilt                            30.0
# azimuth                        180.0
# paneltype                       poly
# cellcategory                Standard
# cod                       2007-10-15
# invertermake                  SatCon
# invertermodel          AE-50-60-PV-D
# panelmake                      Sharp
# panelmodel                  ND-208U2
# year                            2009

# %%
weath['year']=weath['year'].astype(int)

# %%
for i in df.index:
    lat = df.at[i,'lat']
    lon = df.at[i,'lon']
    year = df.at[i,'year']
    for j in weath.index:
        lat = weath.at[i,'lat']
        lon = weath.at[i,'lon']
        year = weath.at[i,'year']
