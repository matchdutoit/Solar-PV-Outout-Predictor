# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv('data/annual_csi_data_for_match.csv', sep=',')

# %%
df0.rename(index=str, columns={"datatime": "datetime"}, inplace=True)
df0['datetime'] = pd.to_datetime(df0['datetime'])
df0.reset_index(drop = True, inplace = True)

# %%
df0.head()
# Out:
#     datetime        lat         lon        city    actualkwh  irradiancekwh  \
# 0 2009-01-01  36.817933 -119.759976      Fresno  215457.0875  278138.156430
# 1 2010-01-01  36.817933 -119.759976      Fresno  193487.6600  261959.131597
# 2 2009-01-01  34.016505 -118.113753  Montebello  288246.6500  416118.658276
# 3 2010-01-01  34.016505 -118.113753  Montebello  252797.2250  409327.120794
# 4 2009-01-01  33.782519 -117.228648      Perris   56125.0000   81674.965560
#
#          pr            mount_type   koeppen  capacity_dc_kw  tilt azimuth  \
# 0  0.774641  Fixed - Roof Mounted  Moderate         161.120  30.0   180.0
# 1  0.738618  Fixed - Roof Mounted  Moderate         161.120  30.0   180.0
# 2  0.692703  Fixed - Roof Mounted  Moderate         243.200  30.0   180.0
# 3  0.617592  Fixed - Roof Mounted  Moderate         243.200  30.0   180.0
# 4  0.687175  Fixed - Roof Mounted  Moderate          46.592  30.0   180.0
#
#   paneltype cellcategory         cod invertermake   invertermodel panelmake  \
# 0      mono      Premium  2008-09-05       SatCon  AE-135-60-PV-A  SunPower
# 1      mono      Premium  2008-09-05       SatCon  AE-135-60-PV-A  SunPower
# 2      mono      Premium  2007-08-01      Xantrex    PV225S-480-P  SunPower
# 3      mono      Premium  2007-08-01      Xantrex    PV225S-480-P  SunPower
# 4      poly     Standard  2007-10-15       SatCon   AE-50-60-PV-D     Sharp
#
#         panelmodel
# 0  PL-EVER-ES-190P
# 1  PL-EVER-ES-190P
# 2  PL-EVER-ES-190P
# 3  PL-EVER-ES-190P
# 4         ND-208U2

# %%
# Function to inspect all value counts at once excluding 'lat' & 'lon'
def val_counts(df):
    for i in df.columns:
        if i not in ['lat', 'lon']:
            print(df[f'{i}'].value_counts())

# %%
def dt_to_year(df):
    df['year'] = np.zeros(df.shape[0])
    for i, el in df['datetime'].iteritems():
        df.at[i,'year'] = el.year
    df['year'] = df['year'].astype(int)
    df.drop(['datetime'], axis=1, inplace=True)

# %%
def pop_year(yr):
    mask = df['year']==yr
    df_new = df[mask]
    return df_new

# %%
def clean_data(df):    
    drop_list = ['city', 'cod', 'panelmodel','invertermodel','lon','pr','invertermake','panelmake']
    df.drop(drop_list, axis=1, inplace=True)
    df.paneltype.fillna(value = 'poly', inplace=True)
    df.mount_type.fillna(value = 'Fixed - Roof Mounted', inplace=True)
    df['cellcategory'].replace('Unknown', 'Standard', inplace=True)
    df['azimuth'].replace('Mixed', 180, inplace=True)
    df['azimuth'] = df['azimuth'].astype(float)
    # df['tilt_mixed'] = (df['tilt']=='Mixed')*1
    df['tilt'].replace('Mixed', round(df['lat'],1),inplace=True)
    df['tilt'] = df['tilt'].astype(float)
    
    for i, el in df['paneltype'].iteritems():
        if el not in ['poly','mono']:
            df.at[i,'paneltype']='other'
    return df

# %%
df = df0.copy()

# %%
df= clean_data(df)

# %%
df['lat'] = round(df['lat'],1)

# %%
tilt = df['tilt'].values.astype(float)
lat = df['lat'].values.astype(float)
az = df['azimuth'].values
df['opt_norm_tilt'] = 1 - abs(tilt-lat)/lat
df['opt_norm_az'] = 1 - abs(az-180)/180

# %%
df.describe()
# Out:
#                lat     actualkwh  irradiancekwh  capacity_dc_kw         tilt  \
# count  8157.000000  8.157000e+03   8.157000e+03     8157.000000  8157.000000
# mean     35.863626  2.859747e+05   3.049015e+05      186.823048    18.001018
# std       2.161258  4.775796e+05   5.143537e+05      299.150419    10.136918
# min      32.600000  7.962080e+02   1.632335e+03        1.150000     0.000000
# 25%      33.800000  8.416804e+03   9.172811e+03        5.775000    10.000000
# 50%      36.300000  8.187200e+04   8.928459e+04       56.400000    18.000000
# 75%      37.800000  3.716450e+05   4.005345e+05      251.160000    23.000000
# max      41.800000  7.867719e+06   9.247761e+06     4725.840000    72.000000
#
#            azimuth  opt_norm_tilt  opt_norm_az
# count  8157.000000    8157.000000  8157.000000
# mean    183.487066       0.501726     0.909978
# std      33.426124       0.278557     0.163570
# min       0.000000      -0.142857     0.000000
# 25%     180.000000       0.292398     0.877778
# 50%     180.000000       0.510204     1.000000
# 75%     184.000000       0.651042     1.000000
# max     270.000000       1.000000     1.000000

# %%
df = pd.get_dummies(df,columns = ['mount_type','koeppen','paneltype','cellcategory'])

# %%
df.head().T
# Out:
#                                                    0                    1  \
# datetime                         2009-01-01 00:00:00  2010-01-01 00:00:00
# lat                                             36.8                 36.8
# actualkwh                                     215457               193488
# irradiancekwh                                 278138               261959
# capacity_dc_kw                                161.12               161.12
# tilt                                              30                   30
# azimuth                                          180                  180
# opt_norm_tilt                               0.815217             0.815217
# opt_norm_az                                        1                    1
# mount_type_1-Axis                                  0                    0
# mount_type_Fixed - Roof Mounted                    1                    1
# koeppen_Arid                                       0                    0
# koeppen_Moderate                                   1                    1
# paneltype_mono                                     1                    1
# paneltype_other                                    0                    0
# paneltype_poly                                     0                    0
# cellcategory_Mixed                                 0                    0
# cellcategory_Premium                               1                    1
# cellcategory_Standard                              0                    0
# cellcategory_Thin Film                             0                    0
#
#                                                    2                    3  \
# datetime                         2009-01-01 00:00:00  2010-01-01 00:00:00
# lat                                               34                   34
# actualkwh                                     288247               252797
# irradiancekwh                                 416119               409327
# capacity_dc_kw                                 243.2                243.2
# tilt                                              30                   30
# azimuth                                          180                  180
# opt_norm_tilt                               0.882353             0.882353
# opt_norm_az                                        1                    1
# mount_type_1-Axis                                  0                    0
# mount_type_Fixed - Roof Mounted                    1                    1
# koeppen_Arid                                       0                    0
# koeppen_Moderate                                   1                    1
# paneltype_mono                                     1                    1
# paneltype_other                                    0                    0
# paneltype_poly                                     0                    0
# cellcategory_Mixed                                 0                    0
# cellcategory_Premium                               1                    1
# cellcategory_Standard                              0                    0
# cellcategory_Thin Film                             0                    0
#
#                                                    4
# datetime                         2009-01-01 00:00:00
# lat                                             33.8
# actualkwh                                      56125
# irradiancekwh                                  81675
# capacity_dc_kw                                46.592
# tilt                                              30
# azimuth                                          180
# opt_norm_tilt                               0.887574
# opt_norm_az                                        1
# mount_type_1-Axis                                  0
# mount_type_Fixed - Roof Mounted                    1
# koeppen_Arid                                       0
# koeppen_Moderate                                   1
# paneltype_mono                                     0
# paneltype_other                                    0
# paneltype_poly                                     1
# cellcategory_Mixed                                 0
# cellcategory_Premium                               0
# cellcategory_Standard                              1
# cellcategory_Thin Film                             0

# %%
df.columns
# Out:
# Index(['datetime', 'lat', 'actualkwh', 'irradiancekwh', 'capacity_dc_kw',
#        'tilt', 'azimuth', 'opt_norm_tilt', 'opt_norm_az', 'mount_type_1-Axis',
#        'mount_type_Fixed - Roof Mounted', 'koeppen_Arid', 'koeppen_Moderate',
#        'paneltype_mono', 'paneltype_other', 'paneltype_poly',
#        'cellcategory_Mixed', 'cellcategory_Premium', 'cellcategory_Standard',
#        'cellcategory_Thin Film'],
#       dtype='object')

# %%
cols = ['actualkwh','capacity_dc_kw','opt_norm_tilt','opt_norm_az', 'mount_type_1-Axis',
       'mount_type_Fixed - Roof Mounted', 'koeppen_Arid', 'koeppen_Moderate',
       'paneltype_mono', 'paneltype_other', 'paneltype_poly',
       'cellcategory_Mixed', 'cellcategory_Premium', 'cellcategory_Standard',
       'cellcategory_Thin Film']
df_new = df.loc[:,cols]

# %%
df_new.head().T
# Out:
#                                              0              1              2  \
# actualkwh                        215457.087500  193487.660000  288246.650000
# capacity_dc_kw                      161.120000     161.120000     243.200000
# opt_norm_tilt                         0.815217       0.815217       0.882353
# opt_norm_az                           1.000000       1.000000       1.000000
# mount_type_1-Axis                     0.000000       0.000000       0.000000
# mount_type_Fixed - Roof Mounted       1.000000       1.000000       1.000000
# koeppen_Arid                          0.000000       0.000000       0.000000
# koeppen_Moderate                      1.000000       1.000000       1.000000
# paneltype_mono                        1.000000       1.000000       1.000000
# paneltype_other                       0.000000       0.000000       0.000000
# paneltype_poly                        0.000000       0.000000       0.000000
# cellcategory_Mixed                    0.000000       0.000000       0.000000
# cellcategory_Premium                  1.000000       1.000000       1.000000
# cellcategory_Standard                 0.000000       0.000000       0.000000
# cellcategory_Thin Film                0.000000       0.000000       0.000000
#
#                                              3             4
# actualkwh                        252797.225000  56125.000000
# capacity_dc_kw                      243.200000     46.592000
# opt_norm_tilt                         0.882353      0.887574
# opt_norm_az                           1.000000      1.000000
# mount_type_1-Axis                     0.000000      0.000000
# mount_type_Fixed - Roof Mounted       1.000000      1.000000
# koeppen_Arid                          0.000000      0.000000
# koeppen_Moderate                      1.000000      1.000000
# paneltype_mono                        1.000000      0.000000
# paneltype_other                       0.000000      0.000000
# paneltype_poly                        0.000000      1.000000
# cellcategory_Mixed                    0.000000      0.000000
# cellcategory_Premium                  1.000000      0.000000
# cellcategory_Standard                 0.000000      1.000000
# cellcategory_Thin Film                0.000000      0.000000

# %%
df_new.corr()
# Out:
#                                  actualkwh  capacity_dc_kw  opt_norm_tilt  \
# actualkwh                         1.000000        0.973386      -0.208641
# capacity_dc_kw                    0.973386        1.000000      -0.203314
# opt_norm_tilt                    -0.208641       -0.203314       1.000000
# opt_norm_az                       0.152814        0.151988       0.091695
# mount_type_1-Axis                 0.440910        0.367960      -0.242940
# mount_type_Fixed - Roof Mounted  -0.440910       -0.367960       0.242940
# koeppen_Arid                     -0.067582       -0.071578      -0.010415
# koeppen_Moderate                  0.067582        0.071578       0.010415
# paneltype_mono                   -0.075434       -0.079075      -0.013149
# paneltype_other                  -0.000155        0.010322      -0.023171
# paneltype_poly                    0.074306        0.073743       0.022112
# cellcategory_Mixed                0.020307        0.034817       0.033324
# cellcategory_Premium             -0.076296       -0.079964      -0.012383
# cellcategory_Standard             0.064678        0.063657       0.019145
# cellcategory_Thin Film            0.022435        0.029079      -0.040794
#
#                                  opt_norm_az  mount_type_1-Axis  \
# actualkwh                           0.152814           0.440910
# capacity_dc_kw                      0.151988           0.367960
# opt_norm_tilt                       0.091695          -0.242940
# opt_norm_az                         1.000000           0.071035
# mount_type_1-Axis                   0.071035           1.000000
# mount_type_Fixed - Roof Mounted    -0.071035          -1.000000
# koeppen_Arid                        0.034861          -0.007621
# koeppen_Moderate                   -0.034861           0.007621
# paneltype_mono                     -0.004475           0.005694
# paneltype_other                     0.021211          -0.001869
# paneltype_poly                     -0.003991          -0.004864
# cellcategory_Mixed                  0.017963          -0.012418
# cellcategory_Premium               -0.004172           0.005477
# cellcategory_Standard              -0.008597          -0.006886
# cellcategory_Thin Film              0.030447           0.011697
#
#                                  mount_type_Fixed - Roof Mounted  \
# actualkwh                                              -0.440910
# capacity_dc_kw                                         -0.367960
# opt_norm_tilt                                           0.242940
# opt_norm_az                                            -0.071035
# mount_type_1-Axis                                      -1.000000
# mount_type_Fixed - Roof Mounted                         1.000000
# koeppen_Arid                                            0.007621
# koeppen_Moderate                                       -0.007621
# paneltype_mono                                         -0.005694
# paneltype_other                                         0.001869
# paneltype_poly                                          0.004864
# cellcategory_Mixed                                      0.012418
# cellcategory_Premium                                   -0.005477
# cellcategory_Standard                                   0.006886
# cellcategory_Thin Film                                 -0.011697
#
#                                  koeppen_Arid  koeppen_Moderate  \
# actualkwh                           -0.067582          0.067582
# capacity_dc_kw                      -0.071578          0.071578
# opt_norm_tilt                       -0.010415          0.010415
# opt_norm_az                          0.034861         -0.034861
# mount_type_1-Axis                   -0.007621          0.007621
# mount_type_Fixed - Roof Mounted      0.007621         -0.007621
# koeppen_Arid                         1.000000         -1.000000
# koeppen_Moderate                    -1.000000          1.000000
# paneltype_mono                       0.180061         -0.180061
# paneltype_other                     -0.042549          0.042549
# paneltype_poly                      -0.160382          0.160382
# cellcategory_Mixed                  -0.018280          0.018280
# cellcategory_Premium                 0.179680         -0.179680
# cellcategory_Standard               -0.163708          0.163708
# cellcategory_Thin Film              -0.033115          0.033115
#
#                                  paneltype_mono  paneltype_other  \
# actualkwh                             -0.075434        -0.000155
# capacity_dc_kw                        -0.079075         0.010322
# opt_norm_tilt                         -0.013149        -0.023171
# opt_norm_az                           -0.004475         0.021211
# mount_type_1-Axis                      0.005694        -0.001869
# mount_type_Fixed - Roof Mounted       -0.005694         0.001869
# koeppen_Arid                           0.180061        -0.042549
# koeppen_Moderate                      -0.180061         0.042549
# paneltype_mono                         1.000000        -0.160906
# paneltype_other                       -0.160906         1.000000
# paneltype_poly                        -0.920554        -0.237403
# cellcategory_Mixed                    -0.069128         0.321365
# cellcategory_Premium                   0.998447        -0.153428
# cellcategory_Standard                 -0.933848        -0.149306
# cellcategory_Thin Film                -0.125230         0.778278
#
#                                  paneltype_poly  cellcategory_Mixed  \
# actualkwh                              0.074306            0.020307
# capacity_dc_kw                         0.073743            0.034817
# opt_norm_tilt                          0.022112            0.033324
# opt_norm_az                           -0.003991            0.017963
# mount_type_1-Axis                     -0.004864           -0.012418
# mount_type_Fixed - Roof Mounted        0.004864            0.012418
# koeppen_Arid                          -0.160382           -0.018280
# koeppen_Moderate                       0.160382            0.018280
# paneltype_mono                        -0.920554           -0.069128
# paneltype_other                       -0.237403            0.321365
# paneltype_poly                         1.000000           -0.059149
# cellcategory_Mixed                    -0.059149            1.000000
# cellcategory_Premium                  -0.921985           -0.069236
# cellcategory_Standard                  0.978218           -0.103465
# cellcategory_Thin Film                -0.184766           -0.013875
#
#                                  cellcategory_Premium  cellcategory_Standard  \
# actualkwh                                   -0.076296               0.064678
# capacity_dc_kw                              -0.079964               0.063657
# opt_norm_tilt                               -0.012383               0.019145
# opt_norm_az                                 -0.004172              -0.008597
# mount_type_1-Axis                            0.005477              -0.006886
# mount_type_Fixed - Roof Mounted             -0.005477               0.006886
# koeppen_Arid                                 0.179680              -0.163708
# koeppen_Moderate                            -0.179680               0.163708
# paneltype_mono                               0.998447              -0.933848
# paneltype_other                             -0.153428              -0.149306
# paneltype_poly                              -0.921985               0.978218
# cellcategory_Mixed                          -0.069236              -0.103465
# cellcategory_Premium                         1.000000              -0.935300
# cellcategory_Standard                       -0.935300               1.000000
# cellcategory_Thin Film                      -0.125425              -0.187434
#
#                                  cellcategory_Thin Film
# actualkwh                                      0.022435
# capacity_dc_kw                                 0.029079
# opt_norm_tilt                                 -0.040794
# opt_norm_az                                    0.030447
# mount_type_1-Axis                              0.011697
# mount_type_Fixed - Roof Mounted               -0.011697
# koeppen_Arid                                  -0.033115
# koeppen_Moderate                               0.033115
# paneltype_mono                                -0.125230
# paneltype_other                                0.778278
# paneltype_poly                                -0.184766
# cellcategory_Mixed                            -0.013875
# cellcategory_Premium                          -0.125425
# cellcategory_Standard                         -0.187434
# cellcategory_Thin Film                         1.000000

# %%
X = df.loc[:,['']]

# %% [markdown]
# ### Dealing with extreme PR values

# %%
####  df.sort_values(by =['pr'], ascending=False)
