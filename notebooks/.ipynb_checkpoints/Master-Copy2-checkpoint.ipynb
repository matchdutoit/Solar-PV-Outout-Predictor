# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %matplotlib inline

# %%
df0 = pd.read_csv('../data/annual_csi_data_for_match.csv', sep=',')

# %% [markdown]
# # Data Cleaning

# %%
df0.rename(index=str, columns={"datatime": "datetime"}, inplace=True)
df0['datetime'] = pd.to_datetime(df0['datetime'])
df0.reset_index(drop = True, inplace = True)

# %%
# Make copy of raw import
df = df0.copy()

# %%
# Function for converting datetime data into just year
def dt_to_year(df):
    df['year'] = np.zeros(df.shape[0])
    for i, el in df['datetime'].iteritems():
        df.at[i,'year'] = el.year
    df['year'] = df['year'].astype(int)
    df.drop(['datetime'], axis=1, inplace=True)

# %%
dt_to_year(df)

# %%
# Convert lat/lon to 2 decimals for NASA API
df.reset_index(drop = True, inplace = True)
df['lat'] = round(df['lat'],2)
df['lon'] = round(df['lon'],2)

# %% [markdown]
# ### Save this df for NASA data to match lat/lon/year in 'Nasa weather merge script'

# %%
df.to_csv('data/readyforweath.csv',index=False)

# %%
df = pd.read_csv('../data/readyforweath.csv')
df.head()
# Out:
#      lat     lon        city    actualkwh  irradiancekwh        pr  \
# 0  36.82 -119.76      Fresno  215457.0875  278138.156430  0.774641
# 1  36.82 -119.76      Fresno  193487.6600  261959.131597  0.738618
# 2  34.02 -118.11  Montebello  288246.6500  416118.658276  0.692703
# 3  34.02 -118.11  Montebello  252797.2250  409327.120794  0.617592
# 4  33.78 -117.23      Perris   56125.0000   81674.965560  0.687175
#
#              mount_type   koeppen  capacity_dc_kw  tilt azimuth paneltype  \
# 0  Fixed - Roof Mounted  Moderate         161.120  30.0   180.0      mono
# 1  Fixed - Roof Mounted  Moderate         161.120  30.0   180.0      mono
# 2  Fixed - Roof Mounted  Moderate         243.200  30.0   180.0      mono
# 3  Fixed - Roof Mounted  Moderate         243.200  30.0   180.0      mono
# 4  Fixed - Roof Mounted  Moderate          46.592  30.0   180.0      poly
#
#   cellcategory         cod invertermake   invertermodel panelmake  \
# 0      Premium  2008-09-05       SatCon  AE-135-60-PV-A  SunPower
# 1      Premium  2008-09-05       SatCon  AE-135-60-PV-A  SunPower
# 2      Premium  2007-08-01      Xantrex    PV225S-480-P  SunPower
# 3      Premium  2007-08-01      Xantrex    PV225S-480-P  SunPower
# 4     Standard  2007-10-15       SatCon   AE-50-60-PV-D     Sharp
#
#         panelmodel  year
# 0  PL-EVER-ES-190P  2009
# 1  PL-EVER-ES-190P  2010
# 2  PL-EVER-ES-190P  2009
# 3  PL-EVER-ES-190P  2010
# 4         ND-208U2  2009

# %% [markdown]
# ### (cont. cleaning)

# %%
def clean_data(df):    
    drop_list = ['city', 'cod', 'panelmodel','invertermodel','pr','lon','invertermake','panelmake']
    df.drop(drop_list, axis=1, inplace=True)
    df.paneltype.fillna(value = 'poly', inplace=True)
    df.mount_type.fillna(value = 'Fixed - Roof Mounted', inplace=True)
    df['cellcategory'].replace('Unknown', 'Standard', inplace=True)
    df['azimuth'].replace('Mixed', 180, inplace=True)
    df['azimuth'] = df['azimuth'].astype(float)
    df['tilt'].replace('Mixed', round(df['lat'],1),inplace=True)
    df['tilt'] = df['tilt'].astype(float)
    df['lat'] = round(df['lat'],1)
    
    # Get opt tilt & azimuth
    tilt = df['tilt'].values.astype(float)
    lat = df['lat'].values.astype(float)
    az = df['azimuth'].values
    df['opt_tilt'] = abs(tilt-lat)
    df['opt_az'] = abs(az-180)
    
    #Group panel types != poly/mono to other
    for i, el in df['paneltype'].iteritems():
        if el not in ['poly','mono']:
            df.at[i,'paneltype']='other'
    return df

# %%
df = clean_data(df)

# %%
df = pd.get_dummies(df,columns = ['mount_type','koeppen','paneltype','cellcategory'], drop_first=True)

# %%
cols = ['actualkwh','capacity_dc_kw','opt_tilt','opt_az', 
       'mount_type_Fixed - Roof Mounted', 'koeppen_Moderate', 'paneltype_other', 'paneltype_poly',
        'cellcategory_Premium', 'cellcategory_Standard',
       'cellcategory_Thin Film','year']
df = df.reindex(cols, axis=1)

# %%
df.to_csv('../data/df_kg_final_withyear.csv',index=False)

# %% [markdown]
# # Let's join the NASA data

# %%
nasa = pd.read_csv('../data/nasa_weather.csv')
csi = pd.read_csv('../data/df_kg_final_withyear.csv')

# %%
print(nasa.shape, csi.shape)
# Out:
# (8157, 6) (8157, 12)

# %%
df_csi_nasa = csi.join(nasa)

# %%
df_csi_nasa.to_csv('../data/df_csi_nasa_withyear.csv',index=False)

# %%
df_csi_nasa.shape
# Out:
# (8157, 18)

# %% [markdown]
# # EDA: Let's look at the data

# %%
df = pd.read_csv('../data/df_csi_nasa_withyear.csv')

# %%
df.describe()
# Out:
#           actualkwh  capacity_dc_kw     opt_tilt       opt_az  \
# count  8.157000e+03     8157.000000  8157.000000  8157.000000
# mean   2.859747e+05      186.823048    17.916354    16.203997
# std    4.775796e+05      299.150419    10.197620    29.442575
# min    7.962080e+02        1.150000     0.000000     0.000000
# 25%    8.416804e+03        5.775000    12.600000     0.000000
# 50%    8.187200e+04       56.400000    17.800000     0.000000
# 75%    3.716450e+05      251.160000    24.500000    22.000000
# max    7.867719e+06     4725.840000    41.800000   180.000000
#
#        mount_type_Fixed - Roof Mounted  koeppen_Moderate  paneltype_other  \
# count                      8157.000000       8157.000000      8157.000000
# mean                          0.980262          0.958195         0.039843
# std                           0.139106          0.200155         0.195602
# min                           0.000000          0.000000         0.000000
# 25%                           1.000000          1.000000         0.000000
# 50%                           1.000000          1.000000         0.000000
# 75%                           1.000000          1.000000         0.000000
# max                           1.000000          1.000000         1.000000
#
#        paneltype_poly  cellcategory_Premium  cellcategory_Standard  \
# count     8157.000000           8157.000000            8157.000000
# mean         0.575947              0.384945               0.582935
# std          0.494229              0.486612               0.493104
# min          0.000000              0.000000               0.000000
# 25%          0.000000              0.000000               0.000000
# 50%          1.000000              0.000000               1.000000
# 75%          1.000000              1.000000               1.000000
# max          1.000000              1.000000               1.000000
#
#        cellcategory_Thin Film         year  ALLSKY_SFC_SW_DWN           KT  \
# count             8157.000000  8157.000000        8157.000000  8157.000000
# mean                 0.024519  2011.768665           5.263445     0.622723
# std                  0.154663     1.470674           0.335985     0.034059
# min                  0.000000  2008.000000           4.290000     0.530000
# 25%                  0.000000  2011.000000           4.980000     0.600000
# 50%                  0.000000  2012.000000           5.310000     0.620000
# 75%                  0.000000  2013.000000           5.530000     0.650000
# max                  1.000000  2014.000000           5.840000     0.690000
#
#            PRECTOT           PS          T2M         WS2M
# count  8157.000000  8157.000000  8157.000000  8157.000000
# mean      1.093841    97.489854    15.694784     2.098124
# std       0.688652     2.943506     2.024554     0.430091
# min       0.140000    76.060000     6.620000     0.190000
# 25%       0.530000    96.050000    13.820000     1.800000
# 50%       0.810000    98.850000    16.040000     2.100000
# 75%       1.610000    99.640000    17.040000     2.340000
# max       4.530000   101.110000    23.560000     4.140000

# %% [markdown]
# ### Plot capactity by year

# %%
yr_vals = df['year'].value_counts()
type(yr_vals)
# Out:
# pandas.core.series.Series

# %%
# Don't know that this is necessary for analysis
yr_vals.sort_index(inplace=True)
fig = plt.figure(figsize=(15,10))
plt.bar(yr_vals.index, yr_vals.values)
plt.xlabel('Year',fontsize='14')
plt.ylabel('# of Systems',fontsize='14')
plt.title('Number of Systems in Dataset by Year',fontsize='18')
plt.grid(linestyle='--',axis='y', alpha=.5);

# %% [markdown]
# ### Distributions

# %%
fig = plt.figure(figsize=(15,10))

hist_x_cap = df['capacity_dc_kw'].values

plt.xlabel('System DC Capacity (kW)', fontsize='14')
plt.ylabel('Frequency',fontsize='14')
# ax0.set_yticks()
# plt.xticks(np.linspace(0,5000,26), fontsize='14', rotation='40')
plt.title('Distribution of Systems by DC Capacity (kW)', fontsize='18')
plt.hist(hist_x_cap, bins=80)
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
hist_x_logcap = np.log10(df['capacity_dc_kw'].values)
fig = plt.figure(figsize=(15,10))
plt.xlabel('System DC Capacity (kW)', fontsize='14')
plt.ylabel('Frequency',fontsize='14')
plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,300000,17), fontsize='14', rotation='40')
plt.xticks(np.linspace(0,4,17), fontsize='14')
plt.title('Distribution of Systems by log DC Capacity (kW)', fontsize='18')
plt.hist(hist_x_logcap, bins=80)
plt.grid(linestyle='--',axis='y', alpha=.5);
# plt.axvspan(np.log10(df['capacity_dc_kw'].values).min(), 1.3, facecolor='g', alpha=0.3)
# plt.axvspan(1.3,3.3, facecolor='m', alpha=0.3)
# (ymn,ymx)= plt.ylim()
# plt.vlines([np.log10(df['capacity_dc_kw'].values).min(), 1.3, 3.3], 0, 300, linestyles='dashed');

# %%
# hist_x_cap = df['capacity_dc_kw'].values
hist_x_logcap = np.log10(df['capacity_dc_kw'].values)
fig = plt.figure(figsize=(15,10))
plt.xlabel('System DC Capacity (kW)', fontsize='14')
plt.ylabel('Frequency',fontsize='14')
plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,300000,17), fontsize='14', rotation='40')
plt.xticks(np.linspace(0,4,17), fontsize='14')
plt.title('Distribution of Systems by DC Capacity (kW)', fontsize='18')
plt.hist(hist_x_logcap, bins=80)
plt.axvspan(np.log10(df['capacity_dc_kw'].values).min(), 1.31, facecolor='g', alpha=0.1)
plt.axvspan(1.31,3.67, facecolor='m', alpha=0.1)
(ymn,ymx)= plt.ylim()
plt.vlines([np.log10(df['capacity_dc_kw'].values).min()], 0, 300, linestyles='dashed')
plt.vlines([1.31, 3.67], 0, 250, linestyles='dashed')
plt.text(1.31, 254, '~20 kW ',horizontalalignment='center',fontsize=16)
plt.text(3.67, 254, '~4700 kW ',horizontalalignment='center',fontsize=16)
plt.text(.67,290,'Residential',horizontalalignment='center',fontsize=16)
plt.text(2.5,290,'Commercial & Industrial',horizontalalignment='center',fontsize=16)
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
# Prodcution Distributions

# %%
# hist_x = df['actualkwh'][df['actualkwh']<500000].values
hist_x = df['actualkwh'].values
fig = plt.figure(figsize=(15,10))
plt.xlabel('Annual kWh Production', fontsize='14')
plt.ylabel('Frequency', fontsize='14')
# plt.xticks(np.linspace(0,500000,21), fontsize='14', rotation='40')
plt.yticks(fontsize='14')
plt.title('Distribution of Systems by Annual Production', fontsize='18')
plt.hist(hist_x, bins=80)
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
hist_x_log = np.log10(df['actualkwh'].values)
fig = plt.figure(figsize=(15,10))
plt.xlabel('log Annual kWh Production', fontsize='14')
plt.ylabel('Frequency',fontsize='14')
plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,8000000,17), fontsize='14', rotation='40')
plt.title('Distribution of Systems by log Annual Production (kWh)', fontsize='18')
plt.hist(hist_x_log, bins=80)
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(hist_x_logcap, hist_x_log,s=2)
plt.grid(linestyle='--',axis='y', alpha=.5)
plt.title("Capacity vs Output for All Systems",fontsize='18')
plt.xlabel("log System Capacity (kW)",fontsize='14')
plt.ylabel("log Actual Annual Output (kWh)",fontsize='14');
# plt.vlines([1.3],3,7, linestyles='dashed');

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(hist_x_logcap, hist_x_log,s=2);
plt.vlines([1.32],3,6.5, linestyles='dashed')
plt.grid(linestyle='--',axis='y', alpha=.5)
plt.title("log Capacity vs log Output for All Systems",fontsize='18')
plt.xlabel("log System Capacity (kW)",fontsize='14')
plt.ylabel("log Actual Annual Output (kWh)",fontsize='14');

# %%
# hist_x = df['actualkwh'][df['actualkwh']<50000].values
# fig = plt.figure(figsize=(15,10))
# plt.xlabel('Annual kWh Production', fontsize='14')
# plt.ylabel('Frequency', fontsize='14')
# plt.xticks(np.linspace(0,50000,21), fontsize='14', rotation='40')
# plt.yticks(fontsize='14')
# plt.title('Distribution of Systems by Annual Production < 50000 kWh', fontsize='18')
# plt.hist(hist_x, bins=50);

# %%
# hist_x = df['capacity_dc_kw'].values
# fig = plt.figure(figsize=(15,10))
# plt.xlabel('System Capacity (kW)', fontsize='14')
# plt.ylabel('Frequency', fontsize='14')
# plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,4000,17),fontsize='14', rotation='50')
# plt.title('Distribution of Systems by System Capacity (kW)', fontsize='18')
# plt.hist(hist_x, bins=100);

# %%
# hist_x = df['capacity_dc_kw'][df['capacity_dc_kw']<600].values
# fig = plt.figure(figsize=(15,10))
# plt.xlabel('System Capacity (kW)', fontsize='14')
# plt.ylabel('Frequency', fontsize='14')
# plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,600,25), fontsize='14', rotation='50')
# plt.title('Distribution of Systems by System Capacity < 600 kW', fontsize='18')
# plt.hist(hist_x, bins=100);

# %%
# hist_x = df['capacity_dc_kw'][df['capacity_dc_kw']<50].values
# fig = plt.figure(figsize=(15,10))
# plt.xlabel('System Capacity (kW)', fontsize='14')
# plt.ylabel('Frequency', fontsize='14')
# plt.yticks(fontsize='14')
# plt.xticks(np.linspace(0,50,11), fontsize='14', rotation='50')
# plt.title('Distribution of Systems by System Capacity < 50 kW', fontsize='18')
# plt.hist(hist_x, bins=50);

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['capacity_dc_kw'].values, df['actualkwh'].values, s=3)
plt.title("Capacity vs Output for All Systems",fontsize='18')
# plt.yticks(np.linspace(0,900000,19))
plt.xticks(np.linspace(0,5000,21), fontsize='14', rotation='50')
plt.xlabel("System Capacity (kW)",fontsize='14')
plt.ylabel("Actual Annual Output (kWh)",fontsize='14')
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['capacity_dc_kw'][df['capacity_dc_kw']<1400].values, df['actualkwh'][df['capacity_dc_kw']<1400].values, s=10)
plt.title("Capacity vs Output for Systems < 1400 kW",fontsize='18')
# plt.yticks(np.linspace(0,900000,19))
plt.xticks(np.linspace(0,1400,15), fontsize='14', rotation='50')
plt.xlabel("System Capacity (kW)",fontsize='14')
plt.ylabel("Actual Annual Output (kWh)",fontsize='14')
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
(df['capacity_dc_kw']>=20).sum()
# Out:
# 4678

# %% [markdown]
# ### Looks like there are cases of over reporting production. Let's remove the outliers

# %%
df['efficiency'] = df['actualkwh'] / df['capacity_dc_kw']

eff_std = df.efficiency.std()
eff_mean = df.efficiency.mean()

# %%
# Removing outliers > 3 std devs away from mean
efficiency_mask = np.abs((eff_mean - df['efficiency'])/eff_std) < 4
efficiency_mask2 = df['efficiency'] < 4360

df = df.loc[efficiency_mask, :]
df = df.loc[efficiency_mask2, :]
print(df.shape)
# Out:
# (8128, 19)

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['capacity_dc_kw'].values, df['actualkwh'].values, s=3)
plt.title("Capacity vs Output for All Systems",fontsize='18')
# plt.yticks(np.linspace(0,900000,19))
plt.xticks(np.linspace(0,5000,21), fontsize='14', rotation='50')
plt.xlabel("System Capacity (kW)",fontsize='14')
plt.ylabel("Actual Annual Output (kWh)",fontsize='14')
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['capacity_dc_kw'][df['capacity_dc_kw']<1400].values, df['actualkwh'][df['capacity_dc_kw']<1400].values, s=10)
plt.title("Capacity vs Output for Systems < 1400 kW",fontsize='18')

plt.xticks(np.linspace(0,1400,15), fontsize='14', rotation='50')
plt.xlabel("System Capacity (kW)",fontsize='14')
plt.ylabel("Actual Annual Output (kWh)",fontsize='14')
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['capacity_dc_kw'].values, df['actualkwh'].values, s=3)
plt.title("Capacity vs Output for All Systems",fontsize='18')

plt.xticks(np.linspace(0,5000,21), fontsize='14', rotation='50')
plt.xlabel("System Capacity (kW)",fontsize='14')
plt.ylabel("Actual Annual Output (kWh)",fontsize='14');

# %%
log_cap = np.log10(df['capacity_dc_kw'].values)
log_prod = np.log10(df['actualkwh'].values)
fig = plt.figure(figsize=(15,10))
plt.scatter(log_cap, log_prod,s=2)
plt.grid(linestyle='--',axis='y', alpha=.5);

# %%
# drop efficiency metric before we export for modeling
df.drop('efficiency', axis=1, inplace=True)
# drop year
df.drop('year',axis=1, inplace=True)

# %%
df.to_csv('../data/df_for_modeling_2.csv', index=False)

# %% [markdown]
# # Modeling

# %% [markdown]
# ### 1. Baseline (mean)

# %%
df_base0 = pd.read_csv('../data/df_for_modeling_2.csv')
df_base = df_base0.copy()
df_res0 = df_base[df_base['capacity_dc_kw']<=20]
df_ci0 = df_base[df_base['capacity_dc_kw']>20]

# %%
df_res0.shape
df_ci0.shape
# Out:
# (4671, 17)

# %%
# df_res_base = df_res0.copy()
df_ci_base = df_ci0.copy()

y = df_ci_base.pop('actualkwh')
df_ci_base['mean'] = np.mean(y)
y_mean = df_ci_base.pop('mean')

# %%
X_train, X_test, y_train, y_test = train_test_split(y_mean, y, train_size=.75, test_size=.25, random_state=42)

# %%
r2 = r2_score(y_test, X_test)
print('Baseline R-squared:',round(r2,3))
# Out:
# Baseline R-squared: -0.001

# %%
base_mse = mean_squared_error(y_test, X_test)
print('Baseline rmse:',round(base_mse**.5,1))
# Out:
# Baseline rmse: 504633.9

# %%
print('Baseline Mean Absolute Error: ', round(mean_absolute_error(y_test,X_test)), 'kWh')
# Out:
# Baseline Mean Absolute Error:  373211.0 kWh

# %% [markdown]
# ### 2. Linear Regression

# %%
# df_res_lr = df_res0.copy()
df_ci_lr = df_ci0.copy()

y = df_ci_lr.pop('actualkwh')
X = df_ci_lr

# Scale features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=.75, test_size=.25, random_state=42)

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
r2 = linreg.score(X_test, y_test)
print('LR R-squared:',round(r2,3))
# Out:
# LR R-squared: 0.937

# %%
y_pred = linreg.predict(X_test)
lr_mse = mean_squared_error(y_test,y_pred)
print('LR rmse: ',round(lr_mse**.5,1))
# Out:
# LR rmse:  126209.3

# %%
print('LR Mean Absolute Error: ', round(mean_absolute_error(y_test,y_pred)), 'kWh')
# Out:
# LR Mean Absolute Error:  57882.0 kWh

# %%
# Plot coefficients
coefs = pd.DataFrame({
    'feature': X.columns,
    'coefficient': linreg.coef_,
    'abs_coef': np.abs(linreg.coef_)
})
coefs.sort_values('abs_coef', inplace=True, ascending=False)

plt.figure(figsize=(15,10))
sns.barplot(x=coefs.coefficient.head(16), y=coefs.feature.head(16), orient='h')

plt.axvline(x=0)
plt.title("LR Coefficients", fontsize='18')
plt.ylabel('Feature', fontsize='14')
plt.yticks(fontsize='14')
# plt.xticks(np.linspace(-50000,450000,11), rotation=50,fontsize='14')
plt.xlabel('Coefficient Value', fontsize='14');

# %%
coefs
# Out:
#                             feature    coefficient       abs_coef
# 0                    capacity_dc_kw  503158.437360  503158.437360
# 3   mount_type_Fixed - Roof Mounted  -59635.535282   59635.535282
# 8             cellcategory_Standard   21597.420344   21597.420344
# 11                               KT   17887.839594   17887.839594
# 7              cellcategory_Premium   12096.522346   12096.522346
# 10                ALLSKY_SFC_SW_DWN   -9481.261207    9481.261207
# 5                   paneltype_other   -8011.288136    8011.288136
# 6                    paneltype_poly   -7924.012337    7924.012337
# 15                             WS2M    7172.628076    7172.628076
# 13                               PS   -6670.504711    6670.504711
# 9            cellcategory_Thin Film    5851.464731    5851.464731
# 12                          PRECTOT   -5394.669627    5394.669627
# 4                  koeppen_Moderate    2796.524726    2796.524726
# 1                          opt_tilt   -2229.091749    2229.091749
# 2                            opt_az   -1868.274590    1868.274590
# 14                              T2M    1463.944428    1463.944428

# %%
df_res_lr['mount_type_Fixed - Roof Mounted'].sum()
# Out:
# 3457

# %%
# Pickle LR model

# %%
pickle.dump(linreg, open('../pickled models/linreg_model_final_res2.pkl', 'wb'))

# %%
pickle.dump(linreg, open('../pickled models/linreg_model_final_ci2.pkl', 'wb'))

# %% [markdown]
# ### 3. Elastic Net

# %%
# Can use same train/test split data
# Grid Search
params = {
    'alpha': np.linspace(.001,.1,10),
    'l1_ratio': np.linspace(0,1,5)
}
en = ElasticNet()
gs_en = GridSearchCV(en, params, cv=3, verbose=1, n_jobs = 4)

gs_en.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.5s
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [Parallel(n_jobs=4)]: Done 150 out of 150 | elapsed:   11.2s finished
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# GridSearchCV(cv=3, error_score='raise',
#        estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'alpha': array([0.001, 0.012, 0.023, 0.034, 0.045, 0.056, 0.067, 0.078, 0.089,
#        0.1  ]), 'l1_ratio': array([0.  , 0.25, 0.5 , 0.75, 1.  ])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
gs_en_bestr2 = gs_en.best_score_
gs_en_params = gs_en.best_params_
gs_en_r2_test = gs_en.score(X_test, y_test)
print('gs_en_bestr2:',gs_en_bestr2)
print('gs_en_params:',gs_en_params)
print('gs_en_r2_test:',gs_en_r2_test)
# Out:
# gs_en_bestr2: 0.9481143586951153
# gs_en_params: {'alpha': 0.012, 'l1_ratio': 0.75}
# gs_en_r2_test: 0.93723467200789

# %%
en = ElasticNet(alpha= .012, l1_ratio=.75)
en.fit(X_train, y_train)
# Out:
# /home/matchdt/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ElasticNet(alpha=0.012, copy_X=True, fit_intercept=True, l1_ratio=0.75,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
en_r2 = en.score(X_test, y_test)
print('EN R-squared:',round(en_r2,3))
y_pred = en.predict(X_test)
en_mse = mean_squared_error(y_test,y_pred)
print('EN rmse: ',round(en_mse**.5,1))
print('EN Mean Absolute Error: ', round(mean_absolute_error(y_test,y_pred)))
# Out:
# EN R-squared: 0.937
# EN rmse:  126358.7
# EN Mean Absolute Error:  57988.0

# %%
coefs_en = pd.DataFrame({
    'feature': X.columns,
    'coefficient': en.coef_,
    'abs_coef': np.abs(en.coef_)
})
coefs_en.sort_values('abs_coef', inplace=True, ascending=False)

plt.figure(figsize=(15,10))
sns.barplot(x=coefs.coefficient.head(16), y=coefs.feature.head(16), orient='h')

plt.axvline(x=0)
plt.title("Elastic Net Coefficients", fontsize='18')
plt.ylabel('Feature', fontsize='14')
plt.yticks(fontsize='14')
# plt.xticks(np.linspace(-50000,450000,11), rotation=50,fontsize='14')
plt.xlabel('Coefficient Value', fontsize='14');

# %%
coefs_en
# Out:
#                             feature    coefficient       abs_coef
# 0                    capacity_dc_kw  501501.068326  501501.068326
# 3   mount_type_Fixed - Roof Mounted  -60034.356107   60034.356107
# 8             cellcategory_Standard   18779.431873   18779.431873
# 11                               KT   16333.727695   16333.727695
# 7              cellcategory_Premium   10673.867293   10673.867293
# 5                   paneltype_other   -8159.370683    8159.370683
# 10                ALLSKY_SFC_SW_DWN   -7492.571957    7492.571957
# 15                             WS2M    6932.583065    6932.583065
# 6                    paneltype_poly   -6525.388755    6525.388755
# 13                               PS   -6369.103817    6369.103817
# 12                          PRECTOT   -5379.645040    5379.645040
# 9            cellcategory_Thin Film    5348.438767    5348.438767
# 4                  koeppen_Moderate    2605.147705    2605.147705
# 2                            opt_az   -2062.012345    2062.012345
# 1                          opt_tilt   -2051.741842    2051.741842
# 14                              T2M    1119.114820    1119.114820

# %%
pickle.dump(en, open('../pickled models/en_model_final_res2.pkl', 'wb'))

# %%
pickle.dump(en, open('../pickled models/en_model_final_ci2.pkl', 'wb'))

# %% [markdown]
# ### 4. Random Forest

# %%
# No scaling necessary
df_ci_rf = df_ci0.copy()
y = df_ci_rf.pop('actualkwh')
X = df_ci_rf

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.75, test_size=.25, random_state=42)

# %%
# Creating gridsearch to find optimal parameters.
params = {
    'max_depth': np.linspace(50,150,6),
    'n_estimators': np.linspace(100,400,4, dtype=int)
}

rf = RandomForestRegressor()
gs_rf = GridSearchCV(rf, params, cv=3, verbose=1,n_jobs=1)

# %%
gs_rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  6.7min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': array([ 50.,  70.,  90., 110., 130., 150.]), 'n_estimators': array([100, 200, 300, 400])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
gs_rf_bestr2 = gs_rf.best_score_
gs_rf_params = gs_rf.best_params_
gs_rf_r2_test = gs_rf.score(X_test, y_test)
print('gs_rf_bestr2:',gs_rf_bestr2)
print('gs_rf_params:',gs_rf_params)
print('gs_rf_r2_test:',gs_rf_r2_test)
# Out:
# gs_rf_bestr2: 0.9507865262855292
# gs_rf_params: {'max_depth': 150.0, 'n_estimators': 200}
# gs_rf_r2_test: 0.9538103347212855

# %%
rf = RandomForestRegressor(max_depth=150, n_estimators=200,n_jobs=4)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=150,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=4,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf_r2 = rf.score(X_test, y_test)
print('RF R-squared:',round(rf_r2,3))
y_pred = rf.predict(X_test)
rf_mse = mean_squared_error(y_test,y_pred)
print('RF rmse: ',round(rf_mse**.5,1))
print('RF Mean Absolute Error: ', round(mean_absolute_error(y_test,y_pred)))
# Out:
# RF R-squared: 0.955
# RF rmse:  107408.2
# RF Mean Absolute Error:  44860.0

# %%
feature_imports = pd.DataFrame({
    'feature': X.columns,
    'importance': rf.feature_importances_
})

feature_imports.sort_values('importance', inplace=True, ascending=False)
plt.figure(figsize=(15,10))
sns.barplot(x=feature_imports.importance.head(16), y=feature_imports.feature.head(16), orient='h')
sns.set_style('white')
sns.despine(offset=10, trim=False)
plt.title('Random Forest Feature Importance', fontsize='18')
plt.xlabel('Importance Value',fontsize='14')
plt.ylabel('Feature',fontsize='14');

# %%
feature_imports = pd.DataFrame({
    'feature': X.columns,
    'importance': rf.feature_importances_
})

feature_imports.sort_values('importance', inplace=True, ascending=False)
plt.figure(figsize=(15,10))
sns.barplot(x=feature_imports.importance.tail(15), y=feature_imports.feature.tail(15), orient='h')
sns.set_style('white')
sns.despine(offset=10, trim=False)
plt.title('Random Forest Feature Importance', fontsize='18')
plt.xlabel('Importance Value',fontsize='14')
plt.ylabel('Feature',fontsize='14');

# %%
pickle.dump(en, open('../pickled models/rf_model_final_res2.pkl', 'wb'))
